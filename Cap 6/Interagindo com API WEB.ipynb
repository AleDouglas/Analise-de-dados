# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data[0]['title']
# Out:
# 'REF: Introduce enum class InferredType'

# %%
import pandas as pd

# %%
ssues = pd.DataFrame(data, columns=['number', 'title',
.....: 'labels', 'state'])

# %%
ssues
# Out:
#     number                                              title
# 0    52517             REF: Introduce enum class InferredType  \
# 1    52516  REGR: fix Series construction from dict for su...
# 2    52515  BUG: RuntimeWarning on describe for a single e...
# 3    52514  TST: Test for setting indexed Series of type s...
# 4    52513  DEV: Upgrade Python development version to 3.9...
# 5    52512                        CI: Uprade mypy min version
# 6    52511                        DEP: Deprecate Series.ravel
# 7    52510  CoW: Investigate copy=False internally in Seri...
# 8    52509                 Make pyarrow a required dependency
# 9    52508  ENH: Try both dayfirst and monthfirst in pd.to...
# 10   52506                                 PERF: dtype checks
# 11   52505  BUG: incorrect reading of CSV  containing larg...
# 12   52503  ENH: Add more dt property/method support for A...
# 13   52501  BUG: The count() API does not consider inf as ...
# ...

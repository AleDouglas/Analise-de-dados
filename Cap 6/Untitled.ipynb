# %%
a = 5

# %%
a
# Out:
# 5

# %%
import numpy as np

# %%
data = {i : np.random.randn() for i in range(7)}

# %%
data
# Out:
# {0: -1.0618252209931003,
#  1: 1.9478938860360746,
#  2: 0.1502856655381329,
#  3: -0.008092203737426381,
#  4: -0.8674252261202968,
#  5: -0.4781830986670904,
#  6: 0.4193012466897795}

# %%
from numpy.random import randn

# %%
data = { i : randn() for i in range(7)}

# %%
data
# Out:
# {0: 0.7387693128391117,
#  1: -1.0895173432107523,
#  2: 0.5720760174382603,
#  3: 0.4061871888876054,
#  4: 0.8516969303867029,
#  5: 0.6367867072393396,
#  6: 0.09314156613346619}

# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x7ff2f4402880>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(randn(50).cumsum())
